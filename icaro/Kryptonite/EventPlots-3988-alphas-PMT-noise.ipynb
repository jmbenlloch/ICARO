# %% [markdown]
# # EVENT PLOTS -- Run 3988-alphas-PMT-noise

# %% [markdown]
# #### Alpha run with almost no drift to study grass

# %%
import datetime
print(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2017-05-17 20:57:53

# %%
# %gui qt
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
import os
import time
import glob
import tables as tb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from invisible_cities.database import load_db
import invisible_cities.reco.peak_functions_c as cpf

# %%
import invisible_cities.reco.tbl_functions as tbl
import invisible_cities.reco.wfm_functions as wfm
import invisible_cities.sierpe.blr as blr
import invisible_cities.reco.peak_functions_c as cpf
from invisible_cities.core.mpl_functions import set_plot_labels
from invisible_cities.reco.params import S12Params, ThresholdParams
from   invisible_cities.core.system_of_units_c import units
import   invisible_cities.core.mpl_functions as mpl

# %%
from icaro.core.gui_functions import fplot_pmt_waveforms, fplot_pmt_signals_vs_time_mus, fplot_signal_vs_time_mus,\
                           fplot_s12, hist_1d, fplot_s2si_map, fill_col_vector, add_simap, fplot_map

# %%
from icaro.core.event_pmaps import EventPmaps, print_s12, print_s2si

# %%
run_number = 3988
DataPMT = load_db.DataPMT(run_number)
DataSiPM = load_db.DataSiPM(run_number)
xs = DataSiPM.X.values
ys = DataSiPM.Y.values
pmt_active = np.nonzero(DataPMT.Active.values)[0].tolist()

# %%
channel_id = DataPMT.ChannelID.values
coeff_blr = abs(DataPMT.coeff_blr.values)
coeff_c = abs(DataPMT.coeff_c .values)
adc_to_pes = abs(DataPMT.adc_to_pes.values)
adc_to_pes_sipm = abs(DataSiPM.adc_to_pes.values)

# %%
coeff_c
# Out:
# array([  1.88850000e-06,   1.94310000e-06,   2.09700000e-06,
#          1.77290000e-06,   1.80740000e-06,   1.61660000e-06,
#          1.80290000e-06,   1.79300000e-06,   1.73240000e-06,
#          1.92810000e-06,   2.05580000e-06,   1.76280000e-06])

# %%
coeff_blr
# Out:
# array([ 0.00078833,  0.00078919,  0.00077511,  0.00077786,  0.00078909,
#         0.00078094,  0.00079408,  0.00077303,  0.00078783,  0.00078242,
#         0.00077667,  0.00078688])

# %%
filename = '/Users/jjgomezcadenas/Projects/ICDATA/LSC/wvfms/3988/dst_waves.gdcsnext.000_3988.root.h5'

# %%
h5rwf = tb.open_file(filename, "r")

# %%
pmtrwf, pmtblr, sipmrwf = tbl.get_vectors(h5rwf)

# %%
NEVT, NPMT, PMTWL = pmtrwf.shape
NEVT, NSIPM, SIPMWL = sipmrwf.shape
print("""
            Number of events in file = {}
            Number of PMTs = {}
            PMTWL = {}
            Number of SiPMs = {}
            SiPMWL = {}
              """.format(NEVT, NPMT, PMTWL,NSIPM, SIPMWL))
# Out:
#             Number of events in file = 170
#             Number of PMTs = 12
#             PMTWL = 52000
#             Number of SiPMs = 1792
#             SiPMWL = 1300

# %%
event=0

# %%
RWF = pmtrwf[event]

# %%
mpl.plot_pmt_waveforms(RWF, zoom=False, window_size=800, figsize=(10,10))

# %%
CWF = blr.deconv_pmt(RWF,
                     coeff_c,
                     coeff_blr,
                     pmt_active,
                     n_baseline  = 48000,
                    thr_trigger = 5)

# %%
mpl.plot_pmt_waveforms(CWF, zoom=False, window_size=800, figsize=(10,10))

# %%
mpl.plot_pmt_signals_vs_time_mus(CWF,
                         pmt_active,
                         t_min      =    0,
                         t_max      = 1300,
                         signal_min =    0,
                         signal_max =  50,
                         figsize=(10,10))

# %%
mpl.plot_pmt_signals_vs_time_mus(CWF,
                         pmt_active,
                         t_min      =    1190,
                         t_max      = 1210,
                         signal_min =    0,
                         signal_max =  2500,
                         figsize=(10,10))

# %%
mpl.plot_pmt_signals_vs_time_mus(CWF,
                         pmt_active,
                         t_min      =    0,
                         t_max      = 1190,
                         signal_min =    0,
                         signal_max =  20,
                         figsize=(10,10))

# %%
mpl.plot_pmt_signals_vs_time_mus(CWF,
                         pmt_active,
                         t_min      =   1203,
                         t_max      = 3200,
                         signal_min =    0,
                         signal_max =  20,
                         figsize=(10,10))

# %%
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                        adc_to_pes,
                                        pmt_active = pmt_active,
                                        n_MAU      = 100,
                                        thr_MAU    = 3)

# %%
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 1190,
                        t_max      = 1210,
                        signal_min =    0,
                        signal_max =  1000,
                        figsize=(6,6))

# %%
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1195,
                        signal_min =    0,
                        signal_max =  5,
                        figsize=(6,6))

# %%
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 1203,
                        t_max      = 3000,
                        signal_min =    0,
                        signal_max =  5,
                        figsize=(6,6))

# %%
def plot_event(event):
    RWF = pmtrwf[event]
    mpl.plot_pmt_waveforms(RWF, zoom=False, window_size=800, figsize=(10,10))
    CWF = blr.deconv_pmt(RWF,
                     coeff_c,
                     coeff_blr,
                     pmt_active,
                     n_baseline  = 100000,
                    thr_trigger = 5)
    mpl.plot_pmt_signals_vs_time_mus(CWF,
                         pmt_active,
                         t_min      =    0,
                         t_max      = 3200,
                         signal_min =    0,
                         signal_max =  1500,
                         figsize=(10,10))
    mpl.plot_pmt_signals_vs_time_mus(CWF,
                         pmt_active,
                         t_min      =    1180,
                         t_max      = 1220,
                         signal_min =    0,
                         signal_max =  2500,
                         figsize=(10,10))
    
    mpl.plot_pmt_signals_vs_time_mus(CWF,
                         pmt_active,
                         t_min      =    0,
                         t_max      = 1180,
                         signal_min =    0,
                         signal_max =  30,
                         figsize=(10,10))
    mpl.plot_pmt_signals_vs_time_mus(CWF,
                         pmt_active,
                         t_min      =  1220,
                         t_max      = 3200,
                         signal_min =    0,
                         signal_max =  30,
                         figsize=(10,10))
    csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                        adc_to_pes,
                                        pmt_active = pmt_active,
                                        n_MAU      = 100,
                                        thr_MAU    = 3)
    mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 1180,
                        t_max      = 1220,
                        signal_min =    0,
                        signal_max =  1000,
                        figsize=(6,6))
    mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1180,
                        signal_min =    0,
                        signal_max =  10,
                        figsize=(6,6))
    mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 1220,
                        t_max      = 3200,
                        signal_min =    0,
                        signal_max =  10,
                        figsize=(6,6))
    
    return csum

# %%
csum = plot_event(event=4)

# %%
csum = plot_event(event=5)

# %%
csum = plot_event(event=6)

# %%
csum = plot_event(event=7)

# %%
csum = plot_event(event=8)
